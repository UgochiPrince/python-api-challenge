# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# # Generate the Cities List by Using the citipy Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# # Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude

# %% [markdown]
# ## Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = {'q': city, 'appid': weather_api_key, 'units': 'metric'}
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        response = requests.get(url, params=city_url)
        
        # Parse the JSON and retrieve data
        city_weather = response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lng = city_weather['coord']['lon']
        city_lat = city_weather['coord']['lat']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | blackmans bay
# Processing Record 2 of Set 1 | waitangi
# Processing Record 3 of Set 1 | cabedelo
# Processing Record 4 of Set 1 | pizarro
# Processing Record 5 of Set 1 | grytviken
# Processing Record 6 of Set 1 | cromer
# Processing Record 7 of Set 1 | howard springs
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | utrik
# Processing Record 10 of Set 1 | kresttsy
# Processing Record 11 of Set 1 | saudarkrokur
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | puerto natales
# Processing Record 14 of Set 1 | sirte
# Processing Record 15 of Set 1 | fort bragg
# Processing Record 16 of Set 1 | anadyr
# Processing Record 17 of Set 1 | guerrero negro
# Processing Record 18 of Set 1 | thompson
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | papatowai
# Processing Record 21 of Set 1 | hithadhoo
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | la sarre
# Processing Record 24 of Set 1 | bredasdorp
# Processing Record 25 of Set 1 | kwolla
# Processing Record 26 of Set 1 | whitehorse
# Processing Record 27 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 28 of Set 1 | east london
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | colonia
# Processing Record 31 of Set 1 | fonadhoo
# City not found. Skipping...
# Processing Record 32 of Set 1 | murghob
# Processing Record 33 of Set 1 | pfalzgrafenweiler
# Processing Record 34 of Set 1 | luanda
# Processing Record 35 of Set 1 | hamilton
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | mejit
# Processing Record 38 of Set 1 | atafu village
# Processing Record 39 of Set 1 | isafjordur
# Processing Record 40 of Set 1 | hayma'
# City not found. Skipping...
# Processing Record 41 of Set 1 | san antonio de pale
# Processing Record 42 of Set 1 | lebyazh'ye
# Processing Record 43 of Set 1 | beyneu
# Processing Record 44 of Set 1 | invercargill
# Processing Record 45 of Set 1 | taoudenni
# Processing Record 46 of Set 1 | iqaluit
# Processing Record 47 of Set 1 | la ronge
# Processing Record 48 of Set 1 | mildura
# Processing Record 49 of Set 1 | tateyama
# Processing Record 50 of Set 1 | enewetak
# Processing Record 0 of Set 2 | saint-philippe
# Processing Record 1 of Set 2 | polyarnyy
# Processing Record 2 of Set 2 | oak ridge
# Processing Record 3 of Set 2 | bojia
# Processing Record 4 of Set 2 | igarka
# Processing Record 5 of Set 2 | bethel
# Processing Record 6 of Set 2 | haiku-pauwela
# Processing Record 7 of Set 2 | ijuw
# City not found. Skipping...
# Processing Record 8 of Set 2 | kingston
# Processing Record 9 of Set 2 | les avirons
# Processing Record 10 of Set 2 | zhaogezhuang
# Processing Record 11 of Set 2 | hotan
# Processing Record 12 of Set 2 | bogale
# Processing Record 13 of Set 2 | kotel'nikovo
# Processing Record 14 of Set 2 | queenstown
# Processing Record 15 of Set 2 | amga
# Processing Record 16 of Set 2 | puerto ayora
# Processing Record 17 of Set 2 | hola
# Processing Record 18 of Set 2 | hawaiian paradise park
# Processing Record 19 of Set 2 | bilibino
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | mwinilunga
# Processing Record 22 of Set 2 | edinburgh of the seven seas
# Processing Record 23 of Set 2 | kharabali
# Processing Record 24 of Set 2 | mugia
# Processing Record 25 of Set 2 | west island
# Processing Record 26 of Set 2 | petropavlovsk-kamchatsky
# Processing Record 27 of Set 2 | praia da vitoria
# Processing Record 28 of Set 2 | kilindoni
# Processing Record 29 of Set 2 | belmonte
# Processing Record 30 of Set 2 | akureyri
# Processing Record 31 of Set 2 | mount gambier
# Processing Record 32 of Set 2 | myshkin
# Processing Record 33 of Set 2 | margaret river
# Processing Record 34 of Set 2 | port mathurin
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | sao joao da barra
# Processing Record 37 of Set 2 | nuku'alofa
# Processing Record 38 of Set 2 | nabire
# Processing Record 39 of Set 2 | summerland
# Processing Record 40 of Set 2 | st. john's
# Processing Record 41 of Set 2 | bom jesus
# Processing Record 42 of Set 2 | crane
# Processing Record 43 of Set 2 | happy valley-goose bay
# Processing Record 44 of Set 2 | college
# Processing Record 45 of Set 2 | klyuchi
# Processing Record 46 of Set 2 | nouadhibou
# Processing Record 47 of Set 2 | san patricio
# Processing Record 48 of Set 2 | jinchang
# Processing Record 49 of Set 2 | cacoal
# Processing Record 0 of Set 3 | saint-joseph
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | gebeit
# Processing Record 3 of Set 3 | constantia
# Processing Record 4 of Set 3 | machico
# Processing Record 5 of Set 3 | uturoa
# Processing Record 6 of Set 3 | punta arenas
# Processing Record 7 of Set 3 | naestved
# Processing Record 8 of Set 3 | minas de marcona
# Processing Record 9 of Set 3 | wailua homesteads
# Processing Record 10 of Set 3 | 'ohonua
# City not found. Skipping...
# Processing Record 11 of Set 3 | aksaray
# Processing Record 12 of Set 3 | al ghayzah
# Processing Record 13 of Set 3 | san luis de la loma
# Processing Record 14 of Set 3 | pangoa
# Processing Record 15 of Set 3 | nar'yan-mar
# Processing Record 16 of Set 3 | taroa
# Processing Record 17 of Set 3 | lompoc
# Processing Record 18 of Set 3 | ban phaeo
# Processing Record 19 of Set 3 | betio village
# Processing Record 20 of Set 3 | harstad
# Processing Record 21 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 22 of Set 3 | qaqortoq
# Processing Record 23 of Set 3 | daulatpur
# Processing Record 24 of Set 3 | georgetown
# Processing Record 25 of Set 3 | afaahiti
# Processing Record 26 of Set 3 | antofagasta
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | bubanza
# Processing Record 29 of Set 3 | divino das laranjeiras
# Processing Record 30 of Set 3 | yorkton
# Processing Record 31 of Set 3 | hadibu
# Processing Record 32 of Set 3 | baker city
# Processing Record 33 of Set 3 | khandyga
# Processing Record 34 of Set 3 | hilo
# Processing Record 35 of Set 3 | sume
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | lethem
# Processing Record 38 of Set 3 | vorgashor
# Processing Record 39 of Set 3 | bandarbeyla
# Processing Record 40 of Set 3 | tazacorte
# Processing Record 41 of Set 3 | conception bay south
# Processing Record 42 of Set 3 | pereiaslav-khmelnytskyi
# Processing Record 43 of Set 3 | alice springs
# Processing Record 44 of Set 3 | minzhu
# Processing Record 45 of Set 3 | guane
# Processing Record 46 of Set 3 | hwange
# Processing Record 47 of Set 3 | am djarass
# City not found. Skipping...
# Processing Record 48 of Set 3 | timimoun
# Processing Record 49 of Set 3 | vila velha
# Processing Record 0 of Set 4 | dudinka
# Processing Record 1 of Set 4 | ytyk-kyuyel'
# City not found. Skipping...
# Processing Record 2 of Set 4 | tazovsky
# Processing Record 3 of Set 4 | sena madureira
# Processing Record 4 of Set 4 | jacmel
# Processing Record 5 of Set 4 | laufen
# Processing Record 6 of Set 4 | naze
# Processing Record 7 of Set 4 | kruisfontein
# Processing Record 8 of Set 4 | tasqala
# Processing Record 9 of Set 4 | loppi
# Processing Record 10 of Set 4 | khovd
# Processing Record 11 of Set 4 | mong cai
# City not found. Skipping...
# Processing Record 12 of Set 4 | korla
# Processing Record 13 of Set 4 | olgii
# City not found. Skipping...
# Processing Record 14 of Set 4 | nikolayevsk-on-amure
# Processing Record 15 of Set 4 | dakhla
# Processing Record 16 of Set 4 | ushuaia
# Processing Record 17 of Set 4 | stanley
# Processing Record 18 of Set 4 | koprubasi
# Processing Record 19 of Set 4 | magadan
# Processing Record 20 of Set 4 | plock
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | avarua
# Processing Record 23 of Set 4 | daru
# Processing Record 24 of Set 4 | merritt
# Processing Record 25 of Set 4 | ghat
# Processing Record 26 of Set 4 | ribeira grande
# Processing Record 27 of Set 4 | fuvahmulah
# City not found. Skipping...
# Processing Record 28 of Set 4 | ladario
# Processing Record 29 of Set 4 | ilulissat
# Processing Record 30 of Set 4 | geraldton
# Processing Record 31 of Set 4 | aykhal
# Processing Record 32 of Set 4 | aasiaat
# Processing Record 33 of Set 4 | ust-nera
# Processing Record 34 of Set 4 | mahibadhoo
# Processing Record 35 of Set 4 | udachny
# Processing Record 36 of Set 4 | vilyuysk
# Processing Record 37 of Set 4 | saldanha
# Processing Record 38 of Set 4 | paracuru
# Processing Record 39 of Set 4 | sabang
# Processing Record 40 of Set 4 | gorontalo
# Processing Record 41 of Set 4 | nalut
# Processing Record 42 of Set 4 | susuman
# Processing Record 43 of Set 4 | tchintabaraden
# Processing Record 44 of Set 4 | fada
# Processing Record 45 of Set 4 | kwale
# Processing Record 46 of Set 4 | umm kaddadah
# Processing Record 47 of Set 4 | freetown
# Processing Record 48 of Set 4 | figuig (centre)
# Processing Record 49 of Set 4 | sibolga
# Processing Record 0 of Set 5 | anar darah
# Processing Record 1 of Set 5 | portland
# Processing Record 2 of Set 5 | selfoss
# Processing Record 3 of Set 5 | tolanaro
# Processing Record 4 of Set 5 | vingt cinq
# City not found. Skipping...
# Processing Record 5 of Set 5 | qui nhon
# Processing Record 6 of Set 5 | qarauyl
# Processing Record 7 of Set 5 | sitka
# Processing Record 8 of Set 5 | dali
# Processing Record 9 of Set 5 | tempio pausania
# Processing Record 10 of Set 5 | chibougamau
# Processing Record 11 of Set 5 | brisas de zicatela
# Processing Record 12 of Set 5 | kill devil hills
# Processing Record 13 of Set 5 | faya-largeau
# Processing Record 14 of Set 5 | ola
# Processing Record 15 of Set 5 | kailua-kona
# Processing Record 16 of Set 5 | vadso
# Processing Record 17 of Set 5 | elliot
# Processing Record 18 of Set 5 | christchurch
# Processing Record 19 of Set 5 | marsa alam
# Processing Record 20 of Set 5 | yambio
# Processing Record 21 of Set 5 | wani
# Processing Record 22 of Set 5 | kavaratti
# Processing Record 23 of Set 5 | tukrah
# Processing Record 24 of Set 5 | cidreira
# Processing Record 25 of Set 5 | flin flon
# Processing Record 26 of Set 5 | vilyuchinsk
# Processing Record 27 of Set 5 | gamboru
# Processing Record 28 of Set 5 | kiunga
# Processing Record 29 of Set 5 | sisimiut
# Processing Record 30 of Set 5 | kaduy
# Processing Record 31 of Set 5 | liupanshui
# City not found. Skipping...
# Processing Record 32 of Set 5 | kodiak
# Processing Record 33 of Set 5 | piti village
# Processing Record 34 of Set 5 | yakeshi
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | morehead city
# Processing Record 37 of Set 5 | mossel bay
# Processing Record 38 of Set 5 | bougouni
# Processing Record 39 of Set 5 | ghanzi
# Processing Record 40 of Set 5 | yuzhno-kurilsk
# Processing Record 41 of Set 5 | tabou
# Processing Record 42 of Set 5 | porto novo
# Processing Record 43 of Set 5 | mostar
# Processing Record 44 of Set 5 | lebu
# Processing Record 45 of Set 5 | ayr
# Processing Record 46 of Set 5 | leava
# Processing Record 47 of Set 5 | paros
# Processing Record 48 of Set 5 | koryazhma
# Processing Record 49 of Set 5 | qaisumah
# Processing Record 0 of Set 6 | manay
# Processing Record 1 of Set 6 | port elizabeth
# Processing Record 2 of Set 6 | tra vinh
# Processing Record 3 of Set 6 | sparti
# Processing Record 4 of Set 6 | manadhoo
# Processing Record 5 of Set 6 | kidal
# Processing Record 6 of Set 6 | raja
# Processing Record 7 of Set 6 | san pedro
# Processing Record 8 of Set 6 | kongolo
# Processing Record 9 of Set 6 | vredenburg
# City not found. Skipping...
# Processing Record 10 of Set 6 | sanghar
# Processing Record 11 of Set 6 | saint-francois
# Processing Record 12 of Set 6 | yenangyaung
# Processing Record 13 of Set 6 | remire-montjoly
# Processing Record 14 of Set 6 | tucuma
# Processing Record 15 of Set 6 | karoi
# Processing Record 16 of Set 6 | kete krachi
# Processing Record 17 of Set 6 | rajaori
# Processing Record 18 of Set 6 | rio grande
# Processing Record 19 of Set 6 | linkou
# Processing Record 20 of Set 6 | kristiansund
# Processing Record 21 of Set 6 | villa gesell
# Processing Record 22 of Set 6 | lihue
# Processing Record 23 of Set 6 | gunnison
# Processing Record 24 of Set 6 | calama
# Processing Record 25 of Set 6 | tannum sands
# Processing Record 26 of Set 6 | peniche
# Processing Record 27 of Set 6 | lodja
# Processing Record 28 of Set 6 | altay
# Processing Record 29 of Set 6 | magnitogorsk
# Processing Record 30 of Set 6 | mil'kovo
# Processing Record 31 of Set 6 | hammerfest
# Processing Record 32 of Set 6 | vityazevo
# Processing Record 33 of Set 6 | tsetserleg
# Processing Record 34 of Set 6 | shevchenko
# Processing Record 35 of Set 6 | as sulayyil
# Processing Record 36 of Set 6 | fale old settlement
# Processing Record 37 of Set 6 | tamarin
# Processing Record 38 of Set 6 | laojunmiao
# Processing Record 39 of Set 6 | las lomitas
# Processing Record 40 of Set 6 | hat yai
# Processing Record 41 of Set 6 | mankera
# Processing Record 42 of Set 6 | nuuk
# Processing Record 43 of Set 6 | qoryooley
# Processing Record 44 of Set 6 | beteza
# City not found. Skipping...
# Processing Record 45 of Set 6 | nemuro
# Processing Record 46 of Set 6 | macae
# Processing Record 47 of Set 6 | caconda
# Processing Record 48 of Set 6 | an nuhud
# Processing Record 49 of Set 6 | sao vicente
# Processing Record 0 of Set 7 | balabac
# Processing Record 1 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 2 of Set 7 | nova xavantina
# Processing Record 3 of Set 7 | kapa'a
# Processing Record 4 of Set 7 | bandar labuan
# Processing Record 5 of Set 7 | fortuna
# Processing Record 6 of Set 7 | nova sintra
# Processing Record 7 of Set 7 | vendas novas
# Processing Record 8 of Set 7 | santiago
# Processing Record 9 of Set 7 | vorkuta
# Processing Record 10 of Set 7 | gadzhiyevo
# Processing Record 11 of Set 7 | port macquarie
# Processing Record 12 of Set 7 | keflavik
# Processing Record 13 of Set 7 | sarangani
# Processing Record 14 of Set 7 | mar del plata
# Processing Record 15 of Set 7 | badger
# Processing Record 16 of Set 7 | bamboo flat
# Processing Record 17 of Set 7 | as saff
# Processing Record 18 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 19 of Set 7 | chambersburg
# Processing Record 20 of Set 7 | tarnogskiy gorodok
# Processing Record 21 of Set 7 | salinopolis
# Processing Record 22 of Set 7 | kapsowar
# City not found. Skipping...
# Processing Record 23 of Set 7 | sayanogorsk
# Processing Record 24 of Set 7 | hajin
# Processing Record 25 of Set 7 | tsiombe
# Processing Record 26 of Set 7 | bei'an
# Processing Record 27 of Set 7 | lenino
# Processing Record 28 of Set 7 | sao jose da coroa grande
# Processing Record 29 of Set 7 | olonkinbyen
# Processing Record 30 of Set 7 | coquimbo
# Processing Record 31 of Set 7 | ancud
# Processing Record 32 of Set 7 | nova vicosa
# Processing Record 33 of Set 7 | tarko-sale
# Processing Record 34 of Set 7 | arsk
# Processing Record 35 of Set 7 | pauini
# Processing Record 36 of Set 7 | nadym
# Processing Record 37 of Set 7 | uyuni
# Processing Record 38 of Set 7 | iskateley
# Processing Record 39 of Set 7 | cozumel
# Processing Record 40 of Set 7 | kargasok
# Processing Record 41 of Set 7 | jati
# Processing Record 42 of Set 7 | ahau
# City not found. Skipping...
# Processing Record 43 of Set 7 | ouellah
# City not found. Skipping...
# Processing Record 44 of Set 7 | burayevo
# Processing Record 45 of Set 7 | devinuwara
# City not found. Skipping...
# Processing Record 46 of Set 7 | el charco
# Processing Record 47 of Set 7 | cheremshan
# Processing Record 48 of Set 7 | whakatane
# Processing Record 49 of Set 7 | rongelap
# Processing Record 0 of Set 8 | nola
# Processing Record 1 of Set 8 | cruz alta
# Processing Record 2 of Set 8 | wynyard
# Processing Record 3 of Set 8 | dadukou
# Processing Record 4 of Set 8 | la'ie
# Processing Record 5 of Set 8 | tlapa de comonfort
# Processing Record 6 of Set 8 | miguel auza
# Processing Record 7 of Set 8 | island harbour
# Processing Record 8 of Set 8 | tacotalpa
# Processing Record 9 of Set 8 | purpe
# Processing Record 10 of Set 8 | gilgit
# Processing Record 11 of Set 8 | dhulia
# Processing Record 12 of Set 8 | agat village
# Processing Record 13 of Set 8 | bubaque
# Processing Record 14 of Set 8 | shitanjing
# Processing Record 15 of Set 8 | carutapera
# Processing Record 16 of Set 8 | papao
# Processing Record 17 of Set 8 | suntar
# Processing Record 18 of Set 8 | kone
# Processing Record 19 of Set 8 | berdigestyakh
# Processing Record 20 of Set 8 | la jagua de ibirico
# Processing Record 21 of Set 8 | kataragama
# City not found. Skipping...
# Processing Record 22 of Set 8 | bida
# Processing Record 23 of Set 8 | el jadid
# Processing Record 24 of Set 8 | revda
# Processing Record 25 of Set 8 | bueng kan
# Processing Record 26 of Set 8 | lata
# Processing Record 27 of Set 8 | yamada
# Processing Record 28 of Set 8 | port lincoln
# Processing Record 29 of Set 8 | karatuzskoye
# Processing Record 30 of Set 8 | cape town
# Processing Record 31 of Set 8 | umea
# Processing Record 32 of Set 8 | hafar al-batin
# Processing Record 33 of Set 8 | kabompo
# Processing Record 34 of Set 8 | sola
# Processing Record 35 of Set 8 | greymouth
# Processing Record 36 of Set 8 | saryozek
# Processing Record 37 of Set 8 | poshekhon'ye
# Processing Record 38 of Set 8 | borogontsy
# Processing Record 39 of Set 8 | dawei
# Processing Record 40 of Set 8 | nishinoomote
# Processing Record 41 of Set 8 | joshimath
# Processing Record 42 of Set 8 | solwezi
# Processing Record 43 of Set 8 | turpan
# Processing Record 44 of Set 8 | la maddalena
# Processing Record 45 of Set 8 | abengourou
# Processing Record 46 of Set 8 | lorengau
# Processing Record 47 of Set 8 | mynamaki
# Processing Record 48 of Set 8 | prince albert
# Processing Record 49 of Set 8 | iquique
# Processing Record 0 of Set 9 | vila franca do campo
# Processing Record 1 of Set 9 | kolobrzeg
# Processing Record 2 of Set 9 | claveria
# Processing Record 3 of Set 9 | smithers
# Processing Record 4 of Set 9 | cherdyn'
# Processing Record 5 of Set 9 | walvis bay
# Processing Record 6 of Set 9 | budva
# Processing Record 7 of Set 9 | sardinata
# Processing Record 8 of Set 9 | santanyi
# Processing Record 9 of Set 9 | aripuana
# Processing Record 10 of Set 9 | fortaleza
# Processing Record 11 of Set 9 | nieuw nickerie
# Processing Record 12 of Set 9 | hau-ri
# Processing Record 13 of Set 9 | plymstock
# Processing Record 14 of Set 9 | mizdah
# Processing Record 15 of Set 9 | codrington
# Processing Record 16 of Set 9 | santa ana
# Processing Record 17 of Set 9 | berezovo
# Processing Record 18 of Set 9 | alofi
# Processing Record 19 of Set 9 | kulia village
# City not found. Skipping...
# Processing Record 20 of Set 9 | lepsy
# Processing Record 21 of Set 9 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 9 | minna
# Processing Record 23 of Set 9 | marathon
# Processing Record 24 of Set 9 | holualoa
# Processing Record 25 of Set 9 | kingscliff
# Processing Record 26 of Set 9 | ivdel'
# Processing Record 27 of Set 9 | keelung
# Processing Record 28 of Set 9 | agde
# Processing Record 29 of Set 9 | brookings
# Processing Record 30 of Set 9 | turkmenbasy
# Processing Record 31 of Set 9 | pingdingshan
# Processing Record 32 of Set 9 | thunder bay
# Processing Record 33 of Set 9 | maceio
# Processing Record 34 of Set 9 | sault ste. marie
# Processing Record 35 of Set 9 | raduzhny
# Processing Record 36 of Set 9 | malabar
# Processing Record 37 of Set 9 | cannonvale
# Processing Record 38 of Set 9 | carnarvon
# Processing Record 39 of Set 9 | ad dilinjat
# Processing Record 40 of Set 9 | saipan
# Processing Record 41 of Set 9 | taulaga
# Processing Record 42 of Set 9 | puerto armuelles
# Processing Record 43 of Set 9 | rechka-vydrino
# Processing Record 44 of Set 9 | ubinskoye
# Processing Record 45 of Set 9 | greenville
# Processing Record 46 of Set 9 | inari
# Processing Record 47 of Set 9 | benjamin aceval
# Processing Record 48 of Set 9 | waingapu
# Processing Record 49 of Set 9 | jayapura
# Processing Record 0 of Set 10 | beledweyne
# Processing Record 1 of Set 10 | tadine
# Processing Record 2 of Set 10 | pointe-noire
# Processing Record 3 of Set 10 | maiwut
# City not found. Skipping...
# Processing Record 4 of Set 10 | hasaki
# Processing Record 5 of Set 10 | krylovskaya
# Processing Record 6 of Set 10 | bouar
# Processing Record 7 of Set 10 | torbat-e jam
# Processing Record 8 of Set 10 | taco pozo
# Processing Record 9 of Set 10 | champerico
# Processing Record 10 of Set 10 | adh dhibiyah
# City not found. Skipping...
# Processing Record 11 of Set 10 | fort irwin
# Processing Record 12 of Set 10 | andergrove
# Processing Record 13 of Set 10 | la passe
# Processing Record 14 of Set 10 | watsa
# Processing Record 15 of Set 10 | pico truncado
# Processing Record 16 of Set 10 | masuguru
# Processing Record 17 of Set 10 | waterloo
# Processing Record 18 of Set 10 | itapirapua
# Processing Record 19 of Set 10 | kapuskasing
# Processing Record 20 of Set 10 | rupert
# Processing Record 21 of Set 10 | desaguadero
# Processing Record 22 of Set 10 | nsanje
# Processing Record 23 of Set 10 | ponta delgada
# Processing Record 24 of Set 10 | palikir - national government center
# Processing Record 25 of Set 10 | sitia
# Processing Record 26 of Set 10 | amasra
# Processing Record 27 of Set 10 | zherdevka
# Processing Record 28 of Set 10 | bogoroditsk
# Processing Record 29 of Set 10 | wad medani
# Processing Record 30 of Set 10 | prince rupert
# Processing Record 31 of Set 10 | charlottetown
# Processing Record 32 of Set 10 | krasnovishersk
# Processing Record 33 of Set 10 | sidi akkacha
# Processing Record 34 of Set 10 | minas de matahambre
# City not found. Skipping...
# Processing Record 35 of Set 10 | chernyshevsk
# Processing Record 36 of Set 10 | pariaman
# Processing Record 37 of Set 10 | liaocheng
# Processing Record 38 of Set 10 | natal
# Processing Record 39 of Set 10 | yazman
# Processing Record 40 of Set 10 | gizo
# Processing Record 41 of Set 10 | glace bay
# Processing Record 42 of Set 10 | lerwick
# Processing Record 43 of Set 10 | imbituba
# Processing Record 44 of Set 10 | okulovka
# Processing Record 45 of Set 10 | phuthaditjhaba
# Processing Record 46 of Set 10 | ta`u
# Processing Record 47 of Set 10 | charters towers
# Processing Record 48 of Set 10 | inhambane
# Processing Record 49 of Set 10 | karymskoye
# Processing Record 0 of Set 11 | griffith
# Processing Record 1 of Set 11 | chivhu
# Processing Record 2 of Set 11 | patterson
# Processing Record 3 of Set 11 | birao
# Processing Record 4 of Set 11 | kokofata
# City not found. Skipping...
# Processing Record 5 of Set 11 | lycksele
# Processing Record 6 of Set 11 | childress
# Processing Record 7 of Set 11 | anna regina
# Processing Record 8 of Set 11 | mccook
# Processing Record 9 of Set 11 | jwaneng
# Processing Record 10 of Set 11 | necochea
# Processing Record 11 of Set 11 | savalou
# Processing Record 12 of Set 11 | karwar
# Processing Record 13 of Set 11 | dalnerechensk
# Processing Record 14 of Set 11 | newman
# Processing Record 15 of Set 11 | labrador city
# Processing Record 16 of Set 11 | kanel
# Processing Record 17 of Set 11 | nyurba
# Processing Record 18 of Set 11 | ko pha ngan
# Processing Record 19 of Set 11 | eirunepe
# Processing Record 20 of Set 11 | al jawf
# Processing Record 21 of Set 11 | batangafo
# Processing Record 22 of Set 11 | khanty-mansiysk
# Processing Record 23 of Set 11 | chui
# Processing Record 24 of Set 11 | zolochiv
# Processing Record 25 of Set 11 | ixmiquilpan
# Processing Record 26 of Set 11 | mount isa
# Processing Record 27 of Set 11 | kassala
# Processing Record 28 of Set 11 | chonchi
# Processing Record 29 of Set 11 | pong nam ron
# Processing Record 30 of Set 11 | schaffhausen
# Processing Record 31 of Set 11 | linhares
# Processing Record 32 of Set 11 | fort mcmurray
# Processing Record 33 of Set 11 | ulsteinvik
# Processing Record 34 of Set 11 | nicoya
# Processing Record 35 of Set 11 | uchaly
# Processing Record 36 of Set 11 | swakopmund
# Processing Record 37 of Set 11 | kalachinsk
# Processing Record 38 of Set 11 | cova figueira
# Processing Record 39 of Set 11 | novodvinsk
# Processing Record 40 of Set 11 | tindouf
# Processing Record 41 of Set 11 | hirara
# Processing Record 42 of Set 11 | ondjiva
# Processing Record 43 of Set 11 | jinghong
# Processing Record 44 of Set 11 | sajir
# Processing Record 45 of Set 11 | scarborough
# Processing Record 46 of Set 11 | kingaroy
# Processing Record 47 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 48 of Set 11 | kayangel
# Processing Record 49 of Set 11 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 0 of Set 12 | rumonge
# Processing Record 1 of Set 12 | hami
# Processing Record 2 of Set 12 | belaya glina
# Processing Record 3 of Set 12 | cestos city
# Processing Record 4 of Set 12 | newnham
# Processing Record 5 of Set 12 | nosy varika
# Processing Record 6 of Set 12 | tura
# Processing Record 7 of Set 12 | taksimo
# Processing Record 8 of Set 12 | njombe
# Processing Record 9 of Set 12 | puerto baquerizo moreno
# Processing Record 10 of Set 12 | vavuniya
# Processing Record 11 of Set 12 | san antonio oeste
# Processing Record 12 of Set 12 | belyy yar
# Processing Record 13 of Set 12 | dryden
# Processing Record 14 of Set 12 | karratha
# Processing Record 15 of Set 12 | jand
# Processing Record 16 of Set 12 | dalandzadgad
# Processing Record 17 of Set 12 | chita
# Processing Record 18 of Set 12 | santa maria da vitoria
# Processing Record 19 of Set 12 | vanimo
# Processing Record 20 of Set 12 | chibuto
# Processing Record 21 of Set 12 | labytnangi
# Processing Record 22 of Set 12 | pacific grove
# Processing Record 23 of Set 12 | n'zeto
# Processing Record 24 of Set 12 | santa terezinha
# Processing Record 25 of Set 12 | beloyarskiy
# Processing Record 26 of Set 12 | kargil
# Processing Record 27 of Set 12 | egilsstadir
# Processing Record 28 of Set 12 | tabarka
# Processing Record 29 of Set 12 | mohr
# Processing Record 30 of Set 12 | cabo san lucas
# Processing Record 31 of Set 12 | malaya vishera
# Processing Record 32 of Set 12 | pandan
# Processing Record 33 of Set 12 | moranbah
# Processing Record 34 of Set 12 | malampaka
# Processing Record 35 of Set 12 | lagunillas
# Processing Record 36 of Set 12 | ma'rib
# Processing Record 37 of Set 12 | jiuquan
# Processing Record 38 of Set 12 | tongren
# Processing Record 39 of Set 12 | surovikino
# Processing Record 40 of Set 12 | shalkar
# Processing Record 41 of Set 12 | cox's bazar
# Processing Record 42 of Set 12 | tawau
# Processing Record 43 of Set 12 | al bayda'
# Processing Record 44 of Set 12 | nogliki
# Processing Record 45 of Set 12 | nkurenkuru
# City not found. Skipping...
# Processing Record 46 of Set 12 | nokha
# Processing Record 47 of Set 12 | santiago de cao
# Processing Record 48 of Set 12 | vuktyl
# Processing Record 49 of Set 12 | ciudad melchor muzquiz
# Processing Record 0 of Set 13 | san andres
# Processing Record 1 of Set 13 | mahina
# Processing Record 2 of Set 13 | bac lieu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          572
# Lat           572
# Lng           572
# Max Temp      572
# Humidity      572
# Cloudiness    572
# Wind Speed    572
# Country       572
# Date          572
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  blackmans bay -43.0167  147.3167     12.08        89          10
# 1       waitangi -43.9535 -176.5597     11.57        91         100
# 2       cabedelo  -6.9811  -34.8339     25.37        82          20
# 3        pizarro   4.9533  -77.3660     26.72        83         100
# 4      grytviken -54.2811  -36.5092      2.50        96          90
#
#    Wind Speed Country        Date
# 0        2.67      AU  1686093479
# 1        0.89      NZ  1686093479
# 2        4.43      BR  1686093282
# 3        2.43      CO  1686093282
# 4        2.04      GS  1686093447

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        blackmans bay -43.0167  147.3167     12.08        89          10
# 1             waitangi -43.9535 -176.5597     11.57        91         100
# 2             cabedelo  -6.9811  -34.8339     25.37        82          20
# 3              pizarro   4.9533  -77.3660     26.72        83         100
# 4            grytviken -54.2811  -36.5092      2.50        96          90
#
#          Wind Speed Country        Date
# City_ID
# 0              2.67      AU  1686093479
# 1              0.89      NZ  1686093479
# 2              4.43      BR  1686093282
# 3              2.43      CO  1686093282
# 4              2.04      GS  1686093447

# %% [markdown]
# # Create the Scatter Plots Requested

# %% [markdown]
# ## Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# Build scatter plot
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], edgecolors='black')

# Set plot title and labels
plt.title('City Max Latitude vs. Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (°C)')

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# Build scatter plot
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], edgecolors='black')

# Set plot title and labels
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')

# Set plot properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Display the plot
plt.show()

# %% [markdown]
# ## Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# Build scatter plot
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], edgecolors='black')

# Set plot title and labels
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')

# Set plot properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Display the plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# Build scatter plot
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], edgecolors='black')

# Set plot title and labels
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')

# Set plot properties
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Display the plot
plt.show()

# %% [markdown]
# # Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x, y, x_label, y_label):
    # Perform linear regression
    slope, intercept, r_value, p_value, std_err = linregress(x, y)

    # Create scatter plot
    plt.scatter(x, y, edgecolor='black')

    # Add regression line
    plt.plot(x, intercept + slope * x, color='red')

    # Set plot title and labels
    plt.title(f'{x_label} vs. {y_label}')
    plt.xlabel(x_label)
    plt.ylabel(y_label)

    # Display regression equation and correlation coefficient
    equation = f'y = {intercept:.2f} + {slope:.2f}x'
    correlation = f'R = {r_value:.2f}'
    plt.text(x.min(), y.max(), equation, ha='left', va='center', color='red')
    plt.text(x.min(), y.max()-10, correlation, ha='left', va='center')
    
    print(f"The r-value is: {r_value}")

    # Display the plot
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0].copy()

# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3         pizarro   4.9533  -77.3660     26.72        83         100
# 5          cromer  52.9312    1.2989     11.19        80          87
# 7           tiksi  71.6872  128.8694      3.00        88          56
# 8           utrik  11.2278  169.8474     27.53        83          83
# 9        kresttsy  58.2452   32.5165     10.93        93          92
#
#          Wind Speed Country        Date
# City_ID
# 3              2.43      CO  1686093282
# 5              5.78      GB  1686093282
# 7              2.16      RU  1686093479
# 8              9.29      MH  1686093480
# 9              1.91      RU  1686093072

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0].copy()

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         blackmans bay -43.0167  147.3167     12.08        89          10
# 1              waitangi -43.9535 -176.5597     11.57        91         100
# 2              cabedelo  -6.9811  -34.8339     25.37        82          20
# 4             grytviken -54.2811  -36.5092      2.50        96          90
# 6        howard springs -12.4970  131.0470     24.95        68           4
#
#          Wind Speed Country        Date
# City_ID
# 0              2.67      AU  1686093479
# 1              0.89      NZ  1686093479
# 2              4.43      BR  1686093282
# 4              2.04      GS  1686093447
# 6              2.81      AU  1686093282

# %% [markdown]
# ## Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Max Temp'], 'Latitude', 'Max Temperature')
# Out:
# The r-value is: -0.7888626080007439

# %%
# Linear regression on Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Max Temp'], 'Latitude', 'Max Temperature')
# Out:
# The r-value is: 0.7798543054877214

# %% [markdown]
# ## Discussion about the linear relationship

# %% [markdown]
# Response goes here

# %% [markdown]
# ## Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: -0.05499831327999719

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Humidity'], 'Latitude', 'Humidity')
# Out:
# The r-value is: 0.011418373440138765

# %% [markdown]
# ## Discussion about the linear relationship:

# %% [markdown]
# Discussion here

# %% [markdown]
# ## Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-value is: -0.06593812469539108

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Cloudiness'], 'Latitude', 'Cloudiness')
# Out:
# The r-value is: 0.07203372905738699

# %% [markdown]
# ## Discussion about the linear relationship:

# %% [markdown]
# Discussion here

# %% [markdown]
# ## Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_linear_regression(northern_hemi_df['Lat'], northern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-value is: -0.08168370667348211

# %%
# Southern Hemisphere
plot_linear_regression(southern_hemi_df['Lat'], southern_hemi_df['Wind Speed'], 'Latitude', 'Wind Speed')
# Out:
# The r-value is: -0.18092705711935958

# %% [markdown]
# ## Discussion about the linear relationship:

# %% [markdown]
# Discussion here
